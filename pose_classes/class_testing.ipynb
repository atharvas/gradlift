# %%
import sys
sys.path.append(".")

from pose import PoseSequence, Pose_2D

# Atharva:
# Please note, this should only be used for videos where a single person is in the frame.

# %%
json_file = "../output/1RchFn-zZDw-results.json"
json_file_2 = "../output/2Tt3qtIe2fs-results.json"

ps = PoseSequence(json_file)
# Out:
# num of frames: 276

# %%
len(ps.pose_sequence_2D)
# Out:
# 276

# %%
#going through each frame
for frame, pose in enumerate(ps.pose_sequence_2D):
    print(frame, pose, "\n", pose.keypoints)
# Out:
# 0 <pose.Pose_2D object at 0x000002A7298FCD30>
# ...
